# %% [markdown]
# pandas:
# *   used for data manupulation(data cleaning,organizing files)
# *   creates dataframes fro excel,csv,txt,DBs
# *   data frames(rows and columns readable by python)
# *   data cleaning by dropping or replacing with mean
# *   visualize the data

# %%
import pandas as pd

# %%
import pandas as pd

# %%
names=["gopika","kusuma","prasanna"]
index=[67,70,72]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 67      gopika
# 70      kusuma
# 72    prasanna
# dtype: object

# %% [markdown]
# importing files
# *   for csv and text:read-csv("file path")
# *   for excel:read-excel("file path")

# %%
df=pd.read_csv("/content/o2Saturation.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a6a5348997ec> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/content/o2Saturation.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4a676c3d8c05> in <cell line: 1>()
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df.tail(10)
# Out:
#       98.6
# 3575  99.6
# 3576  98.8
# 3577  98.6
# 3578  98.6
# 3579  98.6
# 3580  98.6
# 3581  98.6
# 3582  98.6
# 3583  98.6
# 3584  98.6

# %%
df=pd.read_csv("/content/grades_withnulls.csv")

# %%
df.head(10)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1
# 8    Jess        K   NaN   9.1   9.9    A+       1
# 9  Rajini        M   NaN   9.1   9.3     A       0

# %%
df.tail(5)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dft=pd.read_csv("/content/grades.txt")

# %%
dft.head(10)
# Out:
#   Names Initials SEM1 SEM2 SEM3 Grade
# 0                 Joe K 9.8 10 9.9 A+
# 1              Rajesh M 8.9 9.1 9.3 A
# 2              Kissan V 9.9 9.3 9.2 A
# 3                  Mary N 7.7 8 7.1 B
# 4               Jeen K 9.8 9.1 9.9 A+
# 5                 Raj M 8.9 9.1 9.3 A
# 6                Hassan V 9.9 9 9.2 A
# 7                  Mari N 7.7 8 7.1 B
# 8               Jess K 9.8 9.1 9.9 A+
# 9                Rajini M 7 9.1 9.3 A

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ")

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")

# %%
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
df.describe()
# Out:
#             SEM1       SEM2      SEM3     Placed
# count  14.000000  17.000000  16.00000  17.000000
# mean    8.992857   9.000000   9.10000   0.588235
# std     0.929404   0.647109   1.05767   0.507300
# min     7.700000   8.000000   7.00000   0.000000
# 25%     8.000000   9.000000   9.20000   0.000000
# 50%     9.100000   9.100000   9.30000   1.000000
# 75%     9.800000   9.300000   9.90000   1.000000
# max     9.900000  10.000000  10.00000   1.000000

# %%
print(df.shape) #get the noof rows and columns
# Out:
# (17, 7)

# %%
print(df.shape[0]) #get the number of rows
# Out:
# 17

# %%
print(df.shape[1]) #get the number of columns
# Out:
# 7

# %%
print(df.columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
print(df[2:5]) #to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
import pandas as pd

# %%
dft=pd.read_csv("/content/diabetcsv.csv")
print(dft)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
print(dft.iloc[2:1, :3])
# Out:
# Empty DataFrame
# Columns: [preg, plas, pres]
# Index: []

# %% [markdown]
# Accessing data
# *   LOC-accepts column name and index
# *   ILOC-accepts only index

# %%
print(df.loc[2:5,'Names']) #rows of specified columns
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5,'Names'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2b9e87d7d5cd> in <cell line: 1>()
# ----> 1 print(dft.iloc[2:5,'Names'])
#
# NameError: name 'dft' is not defined

# %%
print(df.iloc[2:5])#rows of columns
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
import pandas as pd
dft=pd.read_csv("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a17b3c4f4d3a> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 dft=pd.read_csv("/content/grades.txt")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(df.iloc[2:5, :3]) #iloc[row range,column range]=>index
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum()#to view how many null values in each column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum() #to view total nulls
# Out:
# 4

# %% [markdown]
# dropping nulls

# %%
dfn.dropna() #dropping ll the rows with null values
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc=dfn.dropna()

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn.fillna(5) #null values fill with 5
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# cleaning with mean

# %%
m=dfn['SEM1'].mean()
print(m)
# Out:
# 8.992857142857144

# %%
dfc2=dfn.fillna(m)
print(dfc2)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#drop the duplicates from the above dfc2
dropped=dfc2.drop_duplicates()
print(dropped)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %% [markdown]
# columns

# %%
dfc2.rename(columns={"Grade":"GPA"}) #replace grade column name with gpa
# Out:
#      Names Initials      SEM1  SEM2       SEM3 GPA  Placed
# 0      Joe        K  9.800000  10.0   9.900000  A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000   A       1
# 2   Kissan        V  9.900000   9.8  10.000000   A       0
# 3     Mary        N  7.700000   8.0   8.992857   B       0
# 4     Jeen        K  9.800000   9.1   9.900000  A+       1
# 5      Raj        M  8.900000   9.1   9.300000   A       1
# 6   Hassan        V  9.900000   9.0   9.200000   A       1
# 7     Mari        N  7.700000   8.0   7.100000   B       1
# 8     Jess        K  8.992857   9.1   9.900000  A+       1
# 9   Rajini        M  8.992857   9.1   9.300000   A       0
# 10   Kiran        V  8.992857   9.3   9.200000   A       0
# 11    Maya        N  7.700000   8.0   7.100000   B       0
# 12   Jolin        K  9.800000   9.1   9.900000  A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000   A       1
# 14    Riya        M  9.300000   9.9  10.000000   A       1
# ...

# %%
dfc2.head(5)
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed  AVG_SCORE
# 0     Joe        K   9.8  10.0   9.900000    A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.300000     A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.000000     A       0   9.900000
# 3    Mary        N   7.7   8.0   8.992857     B       0   8.230952
# 4    Jeen        K   9.8   9.1   9.900000    A+       1   9.600000

# %%
dfc2['AVG_SCORE']=(dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3 #df['newcolumn']=values

# %%
dfn[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# SEABORN

# %%
import seaborn as sns

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x="Names",y="SEM2",data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Grade")

# %% [markdown]
# prob:
# 1.load diabaties.csv
# 2.create rel plot with age in y-axis and class as columns

# %%
df=pd.read_csv("/content/diabetcsv.csv")

# %%
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.tail(5)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
import numpy as np
df['index']=np.arange(0,768,1)

# %%
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive      0
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative      1
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive      2
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative      3
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive      4

# %%
sns.relplot(
    data=df,
    x="index",y="age",col="class")

# %% [markdown]
# Inbuilt data sets sea born
# *   tips
# *   dowjones
# *   FMRI
# *   dots
# *   healthexp
# > to load this dataset
#   * syntax:load_dataset("datasetname")

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="sex")

# %%
sns.catplot(
    data=tips,
    x="total_bill",y="day",col="time")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="time")
#hue is creting differance based on the column via colors

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day")

# %%
#style-uses differant markers for different catageories
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="time")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="smoker")

# %%
#color palette:-
#pastel,bright,dark,muted,color blind,deep
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="smoker",palette="colorblind")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="smoker",palette="pastel")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="smoker",palette="dark",kind="violin")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-1799ff4e7405> in <cell line: 1>()
# ----> 1 sns.relplot(
#       2     data=tips,
#       3     x="total_bill",y="tip",hue="day",style="smoker",palette="dark",kind="violin")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     718     else:
#     719         err = f"Plot kind {kind} not recognized"
# --> 720         raise ValueError(err)
#     721
#     722     # Check for attempt to plot onto specific axes and warn
#
# ValueError: Plot kind violin not recognized

# %%
dowjones=sns.load_dataset("dowjones")

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(
    data=dowjones,
    x="Date",y="Price",hue="",kind="line")
# Out:
# <ipython-input-65-db104c12f6db>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(

# %%
sns.catplot(
    data=dowjones,
    x="Date",y="Price")

# %%
fmri=sns.load_dataset("fmri")

# %%
#subjects=no.of patient,region=brain location,
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(
    data=fmri,
    x="timepoint",y="signal",col="event",palette="pastel",kind="line")
# Out:
# <ipython-input-67-d34cce393e6d>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(

# %%
sns.catplot(
    data=fmri,
    x="timepoint",y="signal",col="event",palette="bright",kind="violin")
# Out:
# <ipython-input-77-9e1505400c78>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(

# %%
dots=sns.load_dataset("dots")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %% [markdown]
# Lineafit-lmplot()
#
#
# * plotting the data set
# * fitting the line
# * prediction

# %%
sns.lmplot(x="size",y="tip",data=tips);

# %%
sns.lmplot(x="timepoint",y="signal",data=fmri);

# %% [markdown]
# web scrapping
# *   definition:
#     loading a data from the website.
# * unstructed in html
# * convertible into spreadsheets/DB
# * major websites have their API'S for webscrappinng
#
#
#
# SCRAPPER:
# *  extract all the data from the particular sites
# *  specific data that a user wants
#
#
#  PROCESS:
# *   URL->
# *   HTML code->
# *   elements(CSS/JS)->
# *   scrapes the required data
# *   saves it in required format(CSV,XLSX,JSON)
#
#
#  APPLICATIONS:
# *   Email marketing
# *   Sentiment Analysis
# *   News Monitoring
# *   market research
# *   price monitoring
#
#
#
# LIBRARIES:
# *   Beautiful soup(it scoop out the HTML code,package         bs4-subpackage-beautifulsoup)
# >function
#   * beautiful soup()
#   * find()
#   * find_all()
# *   request(to control out the webpage)
# *   selenium
# *   pandas
# *   webdriver_manager
#
#
# to install any library
# *   !pip install library
# *   !pip install_upgrade library #to upgrade the recent version
# importing subpackage
# *       from parent import the child
# *   importing from bs4 to beautiful soup
